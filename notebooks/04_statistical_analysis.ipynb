# %% [markdown]
# # 04 - Statistical Analysis & Visualizations
# Based on capstone_analysis.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/superstore_cleaned.csv")

# %%
# Monthly Sales Trend
monthly = df.groupby("Month_Name")["Sales"].sum()
monthly.plot(kind="bar", figsize=(12,5))
plt.title("Monthly Sales Trend")
plt.xticks(rotation=45)
plt.show()
