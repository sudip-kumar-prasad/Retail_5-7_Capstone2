# %% [markdown]
# # 00 - Data Extraction
# Based on capstone_analysis.ipynb

# %%
import pandas as pd
import numpy as np

# %%
# Extract / Load Data
df = pd.read_csv('../data/raw/superstore_raw.csv', encoding='latin1')

# %%
df.head()

# %%
df.info()

# %%
print("Rows, Columns:", df.shape)
